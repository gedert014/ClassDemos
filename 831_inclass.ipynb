# %%
import json
import pandas as pd

with open("advertisers_using_your_activity_or_information.json") as file:
    data = json.load(file)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['media', 'label_values', 'fbid'])

# %%
advertisers = data["label_values"][0]["vec"]

# %%
type(advertisers)
# Out:
# list

# %%
advertisers[0]
# Out:
# {'value': 'Indeed'}

# %%
pd.DataFrame(advertisers)
# Out:
#                           value
# 0                        Indeed
# 1                   NOCAP, Inc.
# 2            MediaCom Melbourne
# 3                  Brother Sews
# 4                    SharkNinja
# ...                         ...
# 4778                Royle Media
# 4779               Judge & Jury
# 4780                 Fox 8 News
# 4781  Prospector Baseball Group
# 4782            Kleen Nutrition
#
# [4783 rows x 1 columns]

# %%
df = pd.DataFrame(advertisers)
df.head()
# Out:
#                 value
# 0              Indeed
# 1         NOCAP, Inc.
# 2  MediaCom Melbourne
# 3        Brother Sews
# 4          SharkNinja

# %%
df = df.rename(
    columns={"value": "advertiser_name"})

# %%
df.head()
# Out:
#       advertiser_name
# 0              Indeed
# 1         NOCAP, Inc.
# 2  MediaCom Melbourne
# 3        Brother Sews
# 4          SharkNinja

# %%
df.shape
# Out:
# (4783, 1)

# %%
df.tail()
# Out:
#                 advertiser_name
# 4778                Royle Media
# 4779               Judge & Jury
# 4780                 Fox 8 News
# 4781  Prospector Baseball Group
# 4782            Kleen Nutrition

# %%
df.columns
# Out:
# Index(['advertiser_name'], dtype='str')

# %%
df.info
# Out:
# <bound method DataFrame.info of                 advertiser_name
# 0                        Indeed
# 1                   NOCAP, Inc.
# 2            MediaCom Melbourne
# 3                  Brother Sews
# 4                    SharkNinja
# ...                         ...
# 4778                Royle Media
# 4779               Judge & Jury
# 4780                 Fox 8 News
# 4781  Prospector Baseball Group
# 4782            Kleen Nutrition
#
# [4783 rows x 1 columns]>

# %%
len(df)
# Out:
# 4783

# %%
df["advertiser_name"].nunique()
# Out:
# 4783

# %%
golf_ads = df[df["advertiser_name"].str.contains("golf")]

# %%
golf_ads
# Out:
#              advertiser_name
# 488                  Topgolf
# 678   Pins and aces golf co.
# 1118    clubhousegolfcompany
# 1135           traplinksgolf
# 1298           thegolfarmory
# 2259           pounddiscgolf
# 2704               head golf
# 2915     backswinggolfevents
# 3049              cesky.golf
# 3284      hellforleathergolf
# 3312          thesaltygolfer
# 3502             shankitgolf
# 3544           Dingersgolfco
# 3938            zaleasgolfco
# 4737         golfcreatoropen
